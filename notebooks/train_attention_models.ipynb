# %%
import torch
import gc

if 'trained_resnet' in locals():
    del trained_resnet

gc.collect()

torch.cuda.empty_cache()
print("GPU Memory successfully cleared!")
# Out:
# GPU Memory successfully cleared!

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
sys.path.append(os.path.abspath("../src"))

# %%
from train import train_model

# %%
# Trains my engineered custom attention network layout
trained_cbam = train_model(
    model_name="resnet50_cbam",
    data_dir="/root/keele/oct_data/archive (5)/OCT2017 ",
    num_epochs=10,
    batch_size=128
)
# Out:
# Initializing Training for: RESNET50_CBAM
# Using device: cuda
# Target Dataset Directory: /root/keele/oct_data/archive (5)/OCT2017
# Dataset Loaded | Train Samples: 83484 | Val Samples: 968
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 505MB/s]
# Epoch 1/10: 100%|██████████| 653/653 [02:15<00:00,  4.81it/s]
# Epoch 1 Complete | Train Loss: 0.1682 | Val Acc: 99.07%
# Epoch 2/10: 100%|██████████| 653/653 [02:15<00:00,  4.83it/s]
# Epoch 2 Complete | Train Loss: 0.0930 | Val Acc: 97.62%
# Epoch 3/10: 100%|██████████| 653/653 [02:15<00:00,  4.83it/s]
# Epoch 3 Complete | Train Loss: 0.0721 | Val Acc: 98.86%
# Epoch 4/10: 100%|██████████| 653/653 [02:15<00:00,  4.83it/s]
# Epoch 4 Complete | Train Loss: 0.0573 | Val Acc: 99.90%
# Epoch 5/10: 100%|██████████| 653/653 [02:15<00:00,  4.82it/s]
# Epoch 5 Complete | Train Loss: 0.0490 | Val Acc: 99.79%
# Epoch 6/10: 100%|██████████| 653/653 [02:15<00:00,  4.82it/s]
# Epoch 6 Complete | Train Loss: 0.0410 | Val Acc: 99.59%
# Epoch 7/10: 100%|██████████| 653/653 [02:15<00:00,  4.83it/s]
# Epoch 7 Complete | Train Loss: 0.0362 | Val Acc: 99.69%
# Epoch 8/10: 100%|██████████| 653/653 [02:15<00:00,  4.83it/s]
# Epoch 8 Complete | Train Loss: 0.0353 | Val Acc: 99.48%
# Epoch 9/10: 100%|██████████| 653/653 [02:15<00:00,  4.83it/s]
# Epoch 9 Complete | Train Loss: 0.0298 | Val Acc: 99.48%
# Epoch 10/10: 100%|██████████| 653/653 [02:15<00:00,  4.83it/s]
# Epoch 10 Complete | Train Loss: 0.0290 | Val Acc: 100.00%
# Metrics table saved successfully to: /root/keele/macular-attention-oct/results/tables/resnet50_cbam_training_metrics.csv
# Performance plots saved successfully to: /root/keele/macular-attention-oct/results/figures/resnet50_cbam_curves.png
# Checkpoint successfully stored as: /root/keele/macular-attention-oct/results/resnet50_cbam_baseline.pth
