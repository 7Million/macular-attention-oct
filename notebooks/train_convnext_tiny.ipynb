# %%
# %pip install -r /root/keele/macular-attention-oct/requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# - Using the following code cell to programmatically clear the memory.
# - I am running these notebooks on RunPod.io on a cheap `RTX 4090 x1` so it is blocked from my initial training.
# - This forces PyTorch to release all unused cached VRAM back to the GPU allocator

# %%
import torch
import gc

if 'trained_resnet' in locals():
    del trained_resnet

gc.collect()

torch.cuda.empty_cache()
print("GPU Memory successfully cleared!")
# Out:
# GPU Memory successfully cleared!

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
sys.path.append(os.path.abspath("../src"))

# %%
# Import model function pipeline execution module
from train import train_model

# %%
# Execute experiment inline
trained_convnext = train_model(
    model_name="convnext_tiny",
    data_dir="/root/keele/oct_data/archive (5)/OCT2017 ",
    num_epochs=10,
    batch_size=128
)
# Out:
# Initializing Training for: CONVNEXT_TINY
# Using device: cuda
# Target Dataset Directory: /root/keele/oct_data/archive (5)/OCT2017
# Dataset Loaded | Train Samples: 83484 | Val Samples: 968
# Epoch 1/10: 100%|██████████| 653/653 [02:48<00:00,  3.89it/s]
# Epoch 1 Complete | Train Loss: 0.1754 | Val Acc: 97.52%
# Epoch 2/10: 100%|██████████| 653/653 [02:45<00:00,  3.96it/s]
# Epoch 2 Complete | Train Loss: 0.0952 | Val Acc: 99.69%
# Epoch 3/10: 100%|██████████| 653/653 [02:45<00:00,  3.96it/s]
# Epoch 3 Complete | Train Loss: 0.0776 | Val Acc: 99.59%
# Epoch 4/10: 100%|██████████| 653/653 [02:45<00:00,  3.96it/s]
# Epoch 4 Complete | Train Loss: 0.0623 | Val Acc: 99.59%
# Epoch 5/10: 100%|██████████| 653/653 [02:45<00:00,  3.96it/s]
# Epoch 5 Complete | Train Loss: 0.0538 | Val Acc: 99.90%
# Epoch 6/10: 100%|██████████| 653/653 [02:45<00:00,  3.95it/s]
# Epoch 6 Complete | Train Loss: 0.0463 | Val Acc: 99.79%
# Epoch 7/10: 100%|██████████| 653/653 [02:45<00:00,  3.96it/s]
# ...
